# %% [markdown]
# <a href="https://colab.research.google.com/github/suhan-s255/SUHAN-S-1BM23CS344-AI-LAB/blob/main/AI_LAB_EXAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import heapq

def uniform_cost_search(graph, start, goal):

    priority_queue = [(0, start, [start])]


    visited = set()

    while priority_queue:
        cost, current_node, path = heapq.heappop(priority_queue)


        if current_node == goal:
            return path, cost


        if current_node in visited:
            continue


        visited.add(current_node)


        for neighbor, edge_cost in graph.get(current_node, {}).items():
            if neighbor not in visited:
                new_cost = cost + edge_cost
                new_path = path + [neighbor]
                heapq.heappush(priority_queue, (new_cost, neighbor, new_path))


    return [], float('inf')


graph = {
    'A': {'B': 7, 'C': 3},
    'B': {'C': 2, 'E': 6},
    'C': {'B': 2, 'D': 9},
    'D': {'H': 13, 'E': 3},
    'E': {'F': 2, 'G': 1},
    'F': {},
    'G': {},
    'H': {}
}

start_node = 'A'
goal_node = 'G'

path, cost = uniform_cost_search(graph, start_node, goal_node)

print("Suhan S - 1BM23CS344 - AI LAB")

if path:
    print(f"Lowest cost path from {start_node} to {goal_node}: {path}")
    print(f"Total cost: {cost}")
else:
    print(f"No path found from {start_node} to {goal_node}.")
# Out:
# Suhan S - 1BM23CS344 - AI LAB
# Lowest cost path from A to G: ['A', 'C', 'B', 'E', 'G']
# Total cost: 12

# %%
from collections import deque

def breadth_first_search(graph, start, goal):


    queue = deque([(start, [start])])
    visited = set([start])

    while queue:
        current_node, path = queue.popleft()

        if current_node == goal:
            return path


        for neighbor in graph.get(current_node, {}).keys():
            if neighbor not in visited:
                visited.add(neighbor)
                new_path = path + [neighbor]
                queue.append((neighbor, new_path))

    return []

graph = {
    'A': {'B': 7, 'C': 3},
    'B': {'C': 2, 'E': 6},
    'C': {'B': 2, 'D': 9},
    'D': {'H': 13, 'E': 3},
    'E': {'F': 2, 'G': 1},
    'F': {},
    'G': {},
    'H': {}
}

start_node = 'A'
goal_node = 'G'

bfs_path = breadth_first_search(graph, start_node, goal_node)

print("Suhan S - 1BM23CS344 - AI LAB")

if bfs_path:
    print(f"BFS path from {start_node} to {goal_node}: {bfs_path}")
else:
    print(f"No BFS path found from {start_node} to {goal_node}.")
# Out:
# Suhan S - 1BM23CS344 - AI LAB
# BFS path from A to G: ['A', 'B', 'E', 'G']

# %%
def depth_first_search(graph, start, goal):



    stack = [(start, [start])]
    visited = set()

    while stack:
        current_node, path = stack.pop()

        if current_node == goal:
            return path

        if current_node not in visited:
            visited.add(current_node)


            for neighbor in sorted(graph.get(current_node, {}).keys(), reverse=True):
                if neighbor not in visited:
                    new_path = path + [neighbor]
                    stack.append((neighbor, new_path))

    return []


graph = {
    'A': {'B': 7, 'C': 3},
    'B': {'C': 2, 'E': 6},
    'C': {'B': 2, 'D': 9},
    'D': {'H': 13, 'E': 3},
    'E': {'F': 2, 'G': 1},
    'F': {},
    'G': {},
    'H': {}
}

start_node = 'A'
goal_node = 'G'

dfs_path = depth_first_search(graph, start_node, goal_node)

print("Suhan S - 1BM23CS344 - AI LAB")

if dfs_path:
    print(f"DFS path from {start_node} to {goal_node}: {dfs_path}")
else:
    print(f"No DFS path found from {start_node} to {goal_node}.")
# Out:
# Suhan S - 1BM23CS344 - AI LAB
# DFS path from A to G: ['A', 'B', 'C', 'D', 'E', 'G']
